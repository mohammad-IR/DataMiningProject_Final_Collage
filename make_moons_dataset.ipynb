# %%
from sklearn.datasets import make_moons
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Lasso, SGDClassifier
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot  as plt
import seaborn as sns
# %matplotlib inline

# %%
X, Y =make_moons( n_samples=10000, noise=0.13)

# %%
plt.plot(X[:,0], X[:, 1], 'o' , alpha=0.1)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
lasso_clf = Lasso(alpha=0.2)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=10)

# %%
X_train,X_test
# Out:
# (array([[-0.54871421,  0.93406764],
#         [ 1.82096622, -0.22120268],
#         [ 1.71400615, -0.31427334],
#         ...,
#         [-0.84053976,  0.65677286],
#         [ 1.94466173,  0.29336857],
#         [-0.17615273,  0.51363726]]),
#  array([[ 1.66098772, -0.27974579],
#         [ 1.39038427, -0.35420603],
#         [ 1.06208248, -0.43723122],
#         [-1.0307489 ,  0.08541669],
#         [ 0.53229041, -0.1551058 ],
#         [-0.26332447,  0.95374424],
#         [-0.74658687,  0.81688528],
#         [ 0.51862305, -0.40002516],
#         [ 0.32379981, -0.02905511],
#         [ 0.7406024 ,  0.58293585]]))

# %%
lasso_clf.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.2)

# %%
lasso_clf.score(X_test, Y_test)
# Out:
# 0.1004231575784239

# %%
lasso_clf = Lasso(alpha=0.13)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=20)

# %%
lasso_clf.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.13)

# %%
lasso_clf.score(X_test, Y_test)
# Out:
# 0.3711063783391454

# %%
lasso_clf = Lasso(alpha=0)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=30)

# %%
lasso_clf.fit(X_train, Y_train)
# Out:
# C:\Users\mhose\AppData\Local\Temp/ipykernel_10456/4046117540.py:1: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso_clf.fit(X_train, Y_train)
# C:\Users\mhose\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\mhose\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 444.05041475961616, tolerance: 0.24924963891675017
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0)

# %%
lasso_clf.score(X_test, Y_test)
# Out:
# 0.5713119255055903

# %%
from sklearn.svm import SVC

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
svc_clf = Pipeline([
    ("scaling", StandardScaler()),
    ("svc_clf", SVC())
])

# %%
svc_clf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaling', StandardScaler()), ('svc_clf', SVC())])

# %%
svc_clf.score(X_test, Y_test)
# Out:
# 1.0

# %%
X, Y =make_moons( n_samples=10000, noise=0.20)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=20)

# %%
svc_clf = Pipeline([
    ("scaling", StandardScaler()),
    ("svc_clf", SVC())
]) 
svc_clf.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaling', StandardScaler()), ('svc_clf', SVC())])

# %%
svc_clf.score(X_test, Y_test)
# Out:
# 0.9
